# %% [markdown]
# # load env

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("ANTHROPIC_API_KEY")

# %% [markdown]
# # main api

# %%
from anthropic import Anthropic
client = Anthropic(
    api_key=api_key,
    base_url = "https://api.llmsrelay.com"
)
model =  "claude-haiku-4-5-20251001"

# %% [markdown]
# # helper functions

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text
    })


def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text
    })


def chat(messages, system=None):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages,
        
    }
    if system:
        params["system"] = system
    response = client.messages.create(**params)
    return response.content[0].text

# %% [markdown]
# # main code

# %%
messages = []
system = """
You are an expert Python Developer who write very concise code.
"""

add_user_message(messages, "Write a Python Function that checks a string for duplicate characters.")

answer = chat(messages, system=system)

print(answer)
# Out:
# ```python
# def has_duplicates(s: str) -> bool:
#     """Check if a string contains duplicate characters."""
#     return len(s) != len(set(s))
# ```
# This uses a set to track unique characters. If the set's length differs from the string's length, duplicates exist.
# For case-insensitive comparison:
# ```python
# def has_duplicates(s: str, case_sensitive: bool = True) -> bool:
#     """Check if a string contains duplicate characters."""
#     text = s if case_sensitive else s.lower()
#     return len(text) != len(set(text))
# ```
