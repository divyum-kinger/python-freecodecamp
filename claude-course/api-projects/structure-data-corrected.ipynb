# %% [markdown]
# # load env

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("ANTHROPIC_API_KEY")

# %% [markdown]
# # main api

# %%
from anthropic import Anthropic

client = Anthropic(
    api_key=api_key,
    base_url="https://api.llmsrelay.com",
    timeout=30.0,
)

model = "claude-haiku-4.5"

# %% [markdown]
# # helper functions

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text,
    })


def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text,
    })


def chat(messages, system=None, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system is not None:
        params["system"] = system

    if stop_sequences is not None:
        params["stop_sequences"] = stop_sequences

    response = client.messages.create(**params)
    return response.content[0].text

# %% [markdown]
# # main code

# %%
# messages = []

# add_user_message(
#     messages,
#     "Generate a very short event bridge rule as JSON. Return only valid JSON, no markdown or code fences."
# )

# add_assistant_message(messages, "```json")

# text = chat(messages, None, ["```"])

# print(text)
# Out:
# STATUS: 200
# HEADERS: {'Date': 'Thu, 10 Sep 2026 16:24:22 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'cloudflare', 'x-oneapi-request-id': '202609101624216411861048268d9d6ZzwsTARX', 'x-railway-request-id': 'RW2SNLeIR7a-4u1m9o6EoQ', 'x-request-id': '10497b6a-afe3-4ed3-ad78-d3ba46a23d27', 'Content-Encoding': 'gzip', 'x-hikari-trace': 'sin1.tr00', 'x-railway-edge': 'sin1', 'vary': 'accept-encoding', 'cf-cache-status': 'DYNAMIC', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=QyKek1dUMiX5Vj5MLwgE3XuaNF2e6OxiykD492NfEYtWHPR6iZ1dBSMc8XnKa9yQWWV2bVRToRHS6EOJ%2FHxNYjoNhZ9XJp0yfDxNfQzXCaFfiSq2FOjCp9PGwJ8vUVto18v45w%3D%3D"}]}', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'CF-RAY': 'a38fc8407d65ce45-SIN', 'alt-svc': 'h3=":443"; ma=86400'}
# ...

# %%
messages = []

add_user_message(
    messages,
    """Generate a very short EventBridge rule as JSON."""
)

text = chat(messages)

print(text)
# Out:
# {
#   "Name": "MyEventBridgeRule",
#   "EventBusName": "default",
#   "EventPattern": {
#     "source": ["myapp"],
#     "detail-type": ["myevent"]
#   },
#   "State": "ENABLED",
#   "Targets": [
#     {
#       "Arn": "arn:the platform:lambda:us-east-1:123456789012:function:MyFunction",
#       "Id": "1"
#     }
#   ]
# }
