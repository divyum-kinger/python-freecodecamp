# %% [markdown]
# # load env

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("ANTHROPIC_API_KEY")

# %% [markdown]
# # main api

# %%
from anthropic import Anthropic

client = Anthropic(
    api_key=api_key,
    base_url="https://api.llmsrelay.com"
)

model = "claude-haiku-4-5-20251001"

# %% [markdown]
# # helper functions

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text
    })


def add_assistant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text
    })


def chat(messages, system=None):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages,
        
    }
    if system:
        params["system"] = system
    response = client.messages.create(**params)
    return response.content[0].text

# %% [markdown]
# # running code
# for this, we will use system prompts

# %%
messages = []
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

add_user_message(messages, "5x+2=0. find x.")

answer = chat(messages, system=system)

print(answer)
# Out:
# Let's work through this together!
# First, what's our goal here? We need to find the value of x that makes this equation true.
# To start, look at the equation: 5x + 2 = 0
# What do you think we should do first to get x by itself on one side?
